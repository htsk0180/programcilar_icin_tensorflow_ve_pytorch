# %%
# imdb_rewievs nlp

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds


# datayı tfds ile yükledik.
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)

# datayı böldük.
train_data, test_data = imdb['train'], imdb['test']

#train ve test datalarını hazırlıyoruz.
training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

for s,l in train_data:
    training_sentences.append(str(s.numpy()))
    training_labels.append(l.numpy())

for s,l in test_data:
    testing_sentences.append(str(s.numpy()))
    testing_labels.append(l.numpy())

training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# Tokenize 
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type = 'post'
oov_tok = "<OOV>"
padding_type = 'post'

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# modelimizi kuralım.
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 10
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))

# somuçları çizelim.
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# tahmin 
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBDFC36/imdb_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBDFC36/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBDFC36/imdb_reviews-unsupervised.t…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 6)                 102
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 160,109
# Trainable params: 160,109
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 7s 6ms/step - loss: 0.5609 - accuracy: 0.7425 - val_loss: 0.4237 - val_accuracy: 0.8185
# Epoch 2/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.3388 - accuracy: 0.8606 - val_loss: 0.3695 - val_accuracy: 0.8348
# Epoch 3/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2747 - accuracy: 0.8892 - val_loss: 0.3700 - val_accuracy: 0.8366
# Epoch 4/10
# 782/782 [==============================] - 4s 6ms/step - loss: 0.2384 - accuracy: 0.9069 - val_loss: 0.3841 - val_accuracy: 0.8342
# Epoch 5/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2128 - accuracy: 0.9206 - val_loss: 0.4075 - val_accuracy: 0.8270
# Epoch 6/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1920 - accuracy: 0.9292 - val_loss: 0.4484 - val_accuracy: 0.8151
# Epoch 7/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1747 - accuracy: 0.9366 - val_loss: 0.4640 - val_accuracy: 0.8162
# Epoch 8/10
# 782/782 [==============================] - 4s 6ms/step - loss: 0.1597 - accuracy: 0.9446 - val_loss: 0.4932 - val_accuracy: 0.8147
# Epoch 9/10
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1467 - accuracy: 0.9502 - val_loss: 0.5405 - val_accuracy: 0.8052
# Epoch 10/10
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1352 - accuracy: 0.9554 - val_loss: 0.5707 - val_accuracy: 0.8076
# (10000, 16)

# %%
# BİDİRECTIONAL LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 10
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))

# sonuçlar.
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# tahmin
sentence = ["I really think this is amazing. honest.", "I really think this is amazing. honest."]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 120, 16)           160000
#
#  bidirectional (Bidirectiona  (None, 64)               12544
#  l)
#
#  dense_2 (Dense)             (None, 6)                 390
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 25s 20ms/step - loss: 0.4552 - accuracy: 0.7771 - val_loss: 0.3965 - val_accuracy: 0.8256
# Epoch 2/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2914 - accuracy: 0.8820 - val_loss: 0.4011 - val_accuracy: 0.8218
# Epoch 3/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2305 - accuracy: 0.9119 - val_loss: 0.4334 - val_accuracy: 0.8153
# Epoch 4/10
# 782/782 [==============================] - 16s 21ms/step - loss: 0.1834 - accuracy: 0.9319 - val_loss: 0.5333 - val_accuracy: 0.8104
# Epoch 5/10
# 782/782 [==============================] - 16s 20ms/step - loss: 0.1390 - accuracy: 0.9502 - val_loss: 0.5579 - val_accuracy: 0.8082
# Epoch 6/10
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1089 - accuracy: 0.9623 - val_loss: 0.6184 - val_accuracy: 0.7973
# Epoch 7/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0848 - accuracy: 0.9727 - val_loss: 0.7471 - val_accuracy: 0.8008
# Epoch 8/10
# 782/782 [==============================] - 15s 20ms/step - loss: 0.0698 - accuracy: 0.9777 - val_loss: 0.7851 - val_accuracy: 0.8007
# Epoch 9/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0660 - accuracy: 0.9790 - val_loss: 0.8184 - val_accuracy: 0.8000
# Epoch 10/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0475 - accuracy: 0.9855 - val_loss: 0.8322 - val_accuracy: 0.7868
# 1/1 [==============================] - 1s 704ms/step
# [[0.99837]
#  [0.99837]]
