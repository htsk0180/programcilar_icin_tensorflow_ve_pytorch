# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
sentences = [
 'Dost dost diye nicelerine sarıldım.',
 'Benim sâdık yârim kara topraktır.',
 'Beyhude dolandım boşa yoruldum.',
 'Benim sâdık yârim kara topraktır'
]

# %%
tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'dost': 1, 'benim': 2, 'sâdık': 3, 'yârim': 4, 'kara': 5, 'topraktır': 6, 'diye': 7, 'nicelerine': 8, 'sarıldım': 9, 'beyhude': 10, 'dolandım': 11, 'boşa': 12, 'yoruldum': 13}

# %%
sequences = tokenizer.texts_to_sequences(sentences)
print(sequences)
# Out:
# [[1, 1, 7, 8, 9], [2, 3, 4, 5, 6], [10, 11, 12, 13], [2, 3, 4, 5, 6]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded = pad_sequences(sequences)
print(padded)
# Out:
# [[ 1  1  7  8  9]
#  [ 2  3  4  5  6]
#  [ 0 10 11 12 13]
#  [ 2  3  4  5  6]]

# %%
# pad'leri sondan eklemek istersek
padded = pad_sequences(sequences, padding='post')
print(padded)
# Out:
# [[ 1  1  7  8  9]
#  [ 2  3  4  5  6]
#  [10 11 12 13  0]
#  [ 2  3  4  5  6]]

# %%
# padding'in uzunluğunu da belirtebiliriz.
padded = pad_sequences(sequences, padding='post', maxlen=6)
print(padded)
# Out:
# [[ 1  1  7  8  9  0]
#  [ 2  3  4  5  6  0]
#  [10 11 12 13  0  0]
#  [ 2  3  4  5  6  0]]

# %%
# uzun cümlelerde pad sınırlandırılmasında varsayılan olan cümlenin başından kesilmeyi iptal etmek istiyorsak
padded = pad_sequences(sequences, padding='post', maxlen=6, truncating='post')
print(padded)
# Out:
# [[ 1  1  7  8  9  0]
#  [ 2  3  4  5  6  0]
#  [10 11 12 13  0  0]
#  [ 2  3  4  5  6  0]]
